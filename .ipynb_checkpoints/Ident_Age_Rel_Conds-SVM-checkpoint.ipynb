# %% [markdown]
# # ICR - Identifying Age-Related Conditions
# ## Using Machine Learning to detect conditions with measurements of anonymous characteristics

# %% [markdown]
# In this notebook, we tune, train, and test an SVM model to generate another set of probability estimates.
#
# We start by loading our libraries and reading in our data as we did before.

# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
import warnings
from sklearn.metrics import log_loss
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
warnings.filterwarnings('ignore')

# include all paths to data from local storage location
TRAIN_DATA = os.environ['DATAFILES_PATH'] + '/ICR_Competition/' + 'train.csv'
TEST_DATA = os.environ['DATAFILES_PATH'] + '/ICR_Competition/' + 'test.csv'
GREEKS_DATA = os.environ['DATAFILES_PATH'] + '/ICR_Competition/' + 'greeks.csv'

# load training data
train_df = pd.read_csv(TRAIN_DATA)

# allocate
X = train_df.drop(columns=['Class', 'Id'])
X = pd.get_dummies(X, drop_first=True)

y = train_df['Class'].astype(int)

# %% [markdown]
# ### Training, tuning, and validating the SVM.

# %%
def bal_log_loss(p, y):
    ind0 = np.where(y==0)[0]
    ind1 = np.where(y==1)[0]
    
    N0 = len(ind0)
    N1 = len(ind1)
    
    y0 = (y==0).astype(int)
    y1 = y.astype(int)
    
    return (- np.sum(y0*np.log(p[:, 0]))/N0 - np.sum(y1*np.log(p[:, 1]))/N1) / 2

# %%
# set fold size (5 fold cv)
fold_sz = np.floor(X.shape[0] / 5).astype(int)

verbose = True

accs_total = []
blls_total = []

# loop through each fold
for i in range(5):
    
    print(f"\n*********************** FOLD #{i} ***********************\n")
    
    mask = np.ones(X.shape[0]).astype(bool)
    mask[(i*fold_sz):((i+1)*fold_sz)] = 0
    
    X_train_raw = X.loc[mask,]
    y_train_raw = y.loc[mask,]
    
    X_train_raw['EJ_B'].fillna(value=X_train_raw['EJ_B'].mode())
    X_train_raw = X_train_raw.fillna(value=X_train_raw.mean())
    
    X_train_raw = X_train_raw.to_numpy()
    y_train_raw = y_train_raw.to_numpy()
    
    X_val = X.loc[~mask,]
    y_val = y.loc[~mask,]
    
    X_val['EJ_B'].fillna(value=X.loc[mask,'EJ_B'].mode())
    X_val = X_val.fillna(value=X.loc[mask,].mean())
    
    X_val = X_val.to_numpy()
    y_val = y_val.to_numpy()

    # over sample the diagnosed patients in training set
    oversample = SMOTE(random_state=77, sampling_strategy='minority')
    X_train, y_train = oversample.fit_resample(X_train_raw, y_train_raw)

    # shuffle (in case the model choice may be impacted by ordering)
    shuff_ind = np.random.choice(len(y_train), len(y_train), replace=False)

    X_train = X_train[shuff_ind,]
    y_train = y_train[shuff_ind,]

    # set up grid of hyper-params
    parameters = {
        'C': np.linspace(0, 1, num=50)[1:]
    }

    # init lists of metrics
    accs = []
    blls = []

    # init counter
    trial = 1

    for c in parameters['C']:

                # fit SVM (remember to scale inputs first)
                classifier = make_pipeline(StandardScaler(), SVC(gamma='auto', 
                                                                 kernel='rbf', 
                                                                 C=c, 
                                                                 probability=True))
                classifier.fit(X_train, y_train)
                
                # collect val probabilities 
                probs = classifier.predict_proba(X_val)

                # collect val accuracy 
                acc = np.mean(np.argmax(probs, 1) == y_val)
                
                # collect val balanced logarithmic loss
                bll = bal_log_loss(probs, y_val)

                # store val metrics
                accs.append(acc)
                blls.append(bll)

                if verbose:
                    print(f'Trail #{trial:2} || Using:  C={c} || Balanced Log-Loss = {bll:.5f}')

                trial += 1
            
    accs_total.append(accs)
    blls_total.append(blls)
# Out:
# *********************** FOLD #0 ***********************
#
# Trail # 1 || Using:  C=0.02040816326530612 || Balanced Log-Loss = 0.62158
# Trail # 2 || Using:  C=0.04081632653061224 || Balanced Log-Loss = 0.38214
# Trail # 3 || Using:  C=0.061224489795918366 || Balanced Log-Loss = 0.39067
# Trail # 4 || Using:  C=0.08163265306122448 || Balanced Log-Loss = 0.38319
# Trail # 5 || Using:  C=0.1020408163265306 || Balanced Log-Loss = 0.38687
# Trail # 6 || Using:  C=0.12244897959183673 || Balanced Log-Loss = 0.37751
# Trail # 7 || Using:  C=0.14285714285714285 || Balanced Log-Loss = 0.38224
# Trail # 8 || Using:  C=0.16326530612244897 || Balanced Log-Loss = 0.38243
# Trail # 9 || Using:  C=0.18367346938775508 || Balanced Log-Loss = 0.38467
# Trail #10 || Using:  C=0.2040816326530612 || Balanced Log-Loss = 0.38745
# Trail #11 || Using:  C=0.22448979591836732 || Balanced Log-Loss = 0.39873
# Trail #12 || Using:  C=0.24489795918367346 || Balanced Log-Loss = 0.40371
# Trail #13 || Using:  C=0.26530612244897955 || Balanced Log-Loss = 0.40961
# Trail #14 || Using:  C=0.2857142857142857 || Balanced Log-Loss = 0.41305
# Trail #15 || Using:  C=0.3061224489795918 || Balanced Log-Loss = 0.42658
# Trail #16 || Using:  C=0.32653061224489793 || Balanced Log-Loss = 0.41795
# Trail #17 || Using:  C=0.3469387755102041 || Balanced Log-Loss = 0.42200
# Trail #18 || Using:  C=0.36734693877551017 || Balanced Log-Loss = 0.41503
# Trail #19 || Using:  C=0.3877551020408163 || Balanced Log-Loss = 0.41539
# Trail #20 || Using:  C=0.4081632653061224 || Balanced Log-Loss = 0.41745
# Trail #21 || Using:  C=0.42857142857142855 || Balanced Log-Loss = 0.42256
# Trail #22 || Using:  C=0.44897959183673464 || Balanced Log-Loss = 0.41732
# Trail #23 || Using:  C=0.4693877551020408 || Balanced Log-Loss = 0.41236
# Trail #24 || Using:  C=0.4897959183673469 || Balanced Log-Loss = 0.42290
# Trail #25 || Using:  C=0.5102040816326531 || Balanced Log-Loss = 0.42206
# Trail #26 || Using:  C=0.5306122448979591 || Balanced Log-Loss = 0.41793
# Trail #27 || Using:  C=0.5510204081632653 || Balanced Log-Loss = 0.40782
# Trail #28 || Using:  C=0.5714285714285714 || Balanced Log-Loss = 0.40336
# Trail #29 || Using:  C=0.5918367346938775 || Balanced Log-Loss = 0.41616
# Trail #30 || Using:  C=0.6122448979591836 || Balanced Log-Loss = 0.41461
# Trail #31 || Using:  C=0.6326530612244897 || Balanced Log-Loss = 0.43700
# Trail #32 || Using:  C=0.6530612244897959 || Balanced Log-Loss = 0.43204
# Trail #33 || Using:  C=0.673469387755102 || Balanced Log-Loss = 0.44521
# Trail #34 || Using:  C=0.6938775510204082 || Balanced Log-Loss = 0.42067
# Trail #35 || Using:  C=0.7142857142857142 || Balanced Log-Loss = 0.44131
# Trail #36 || Using:  C=0.7346938775510203 || Balanced Log-Loss = 0.43787
# Trail #37 || Using:  C=0.7551020408163265 || Balanced Log-Loss = 0.43469
# Trail #38 || Using:  C=0.7755102040816326 || Balanced Log-Loss = 0.45103
# Trail #39 || Using:  C=0.7959183673469387 || Balanced Log-Loss = 0.43417
# Trail #40 || Using:  C=0.8163265306122448 || Balanced Log-Loss = 0.42642
# Trail #41 || Using:  C=0.836734693877551 || Balanced Log-Loss = 0.44790
# Trail #42 || Using:  C=0.8571428571428571 || Balanced Log-Loss = 0.46041
# Trail #43 || Using:  C=0.8775510204081632 || Balanced Log-Loss = 0.45529
# Trail #44 || Using:  C=0.8979591836734693 || Balanced Log-Loss = 0.44686
# Trail #45 || Using:  C=0.9183673469387754 || Balanced Log-Loss = 0.45955
# Trail #46 || Using:  C=0.9387755102040816 || Balanced Log-Loss = 0.47171
# Trail #47 || Using:  C=0.9591836734693877 || Balanced Log-Loss = 0.46920
# Trail #48 || Using:  C=0.9795918367346939 || Balanced Log-Loss = 0.48011
# Trail #49 || Using:  C=1.0 || Balanced Log-Loss = 0.46000
#
# *********************** FOLD #1 ***********************
#
# Trail # 1 || Using:  C=0.02040816326530612 || Balanced Log-Loss = 0.61923
# Trail # 2 || Using:  C=0.04081632653061224 || Balanced Log-Loss = 0.54481
# Trail # 3 || Using:  C=0.061224489795918366 || Balanced Log-Loss = 0.53302
# Trail # 4 || Using:  C=0.08163265306122448 || Balanced Log-Loss = 0.51629
# Trail # 5 || Using:  C=0.1020408163265306 || Balanced Log-Loss = 0.49485
# Trail # 6 || Using:  C=0.12244897959183673 || Balanced Log-Loss = 0.47506
# Trail # 7 || Using:  C=0.14285714285714285 || Balanced Log-Loss = 0.47026
# Trail # 8 || Using:  C=0.16326530612244897 || Balanced Log-Loss = 0.46203
# Trail # 9 || Using:  C=0.18367346938775508 || Balanced Log-Loss = 0.46182
# Trail #10 || Using:  C=0.2040816326530612 || Balanced Log-Loss = 0.45622
# Trail #11 || Using:  C=0.22448979591836732 || Balanced Log-Loss = 0.45952
# Trail #12 || Using:  C=0.24489795918367346 || Balanced Log-Loss = 0.46326
# Trail #13 || Using:  C=0.26530612244897955 || Balanced Log-Loss = 0.47115
# Trail #14 || Using:  C=0.2857142857142857 || Balanced Log-Loss = 0.48120
# Trail #15 || Using:  C=0.3061224489795918 || Balanced Log-Loss = 0.48005
# Trail #16 || Using:  C=0.32653061224489793 || Balanced Log-Loss = 0.47715
# Trail #17 || Using:  C=0.3469387755102041 || Balanced Log-Loss = 0.48174
# Trail #18 || Using:  C=0.36734693877551017 || Balanced Log-Loss = 0.49765
# Trail #19 || Using:  C=0.3877551020408163 || Balanced Log-Loss = 0.50377
# Trail #20 || Using:  C=0.4081632653061224 || Balanced Log-Loss = 0.51293
# Trail #21 || Using:  C=0.42857142857142855 || Balanced Log-Loss = 0.51512
# Trail #22 || Using:  C=0.44897959183673464 || Balanced Log-Loss = 0.52033
# Trail #23 || Using:  C=0.4693877551020408 || Balanced Log-Loss = 0.52116
# Trail #24 || Using:  C=0.4897959183673469 || Balanced Log-Loss = 0.52252
# Trail #25 || Using:  C=0.5102040816326531 || Balanced Log-Loss = 0.52674
# Trail #26 || Using:  C=0.5306122448979591 || Balanced Log-Loss = 0.52232
# Trail #27 || Using:  C=0.5510204081632653 || Balanced Log-Loss = 0.53398
# Trail #28 || Using:  C=0.5714285714285714 || Balanced Log-Loss = 0.57156
# Trail #29 || Using:  C=0.5918367346938775 || Balanced Log-Loss = 0.55898
# Trail #30 || Using:  C=0.6122448979591836 || Balanced Log-Loss = 0.55086
# Trail #31 || Using:  C=0.6326530612244897 || Balanced Log-Loss = 0.56319
# Trail #32 || Using:  C=0.6530612244897959 || Balanced Log-Loss = 0.57368
# Trail #33 || Using:  C=0.673469387755102 || Balanced Log-Loss = 0.57357
# Trail #34 || Using:  C=0.6938775510204082 || Balanced Log-Loss = 0.58146
# Trail #35 || Using:  C=0.7142857142857142 || Balanced Log-Loss = 0.59216
# Trail #36 || Using:  C=0.7346938775510203 || Balanced Log-Loss = 0.60139
# Trail #37 || Using:  C=0.7551020408163265 || Balanced Log-Loss = 0.57324
# Trail #38 || Using:  C=0.7755102040816326 || Balanced Log-Loss = 0.58190
# Trail #39 || Using:  C=0.7959183673469387 || Balanced Log-Loss = 0.56185
# Trail #40 || Using:  C=0.8163265306122448 || Balanced Log-Loss = 0.56161
# Trail #41 || Using:  C=0.836734693877551 || Balanced Log-Loss = 0.63134
# Trail #42 || Using:  C=0.8571428571428571 || Balanced Log-Loss = 0.61793
# Trail #43 || Using:  C=0.8775510204081632 || Balanced Log-Loss = 0.60709
# Trail #44 || Using:  C=0.8979591836734693 || Balanced Log-Loss = 0.58553
# Trail #45 || Using:  C=0.9183673469387754 || Balanced Log-Loss = 0.60265
# Trail #46 || Using:  C=0.9387755102040816 || Balanced Log-Loss = 0.58064
# Trail #47 || Using:  C=0.9591836734693877 || Balanced Log-Loss = 0.59168
# Trail #48 || Using:  C=0.9795918367346939 || Balanced Log-Loss = 0.62705
# Trail #49 || Using:  C=1.0 || Balanced Log-Loss = 0.59993
#
# *********************** FOLD #2 ***********************
#
# Trail # 1 || Using:  C=0.02040816326530612 || Balanced Log-Loss = 0.61538
# Trail # 2 || Using:  C=0.04081632653061224 || Balanced Log-Loss = 0.40729
# Trail # 3 || Using:  C=0.061224489795918366 || Balanced Log-Loss = 0.38841
# Trail # 4 || Using:  C=0.08163265306122448 || Balanced Log-Loss = 0.38756
# Trail # 5 || Using:  C=0.1020408163265306 || Balanced Log-Loss = 0.38368
# Trail # 6 || Using:  C=0.12244897959183673 || Balanced Log-Loss = 0.37494
# Trail # 7 || Using:  C=0.14285714285714285 || Balanced Log-Loss = 0.36214
# Trail # 8 || Using:  C=0.16326530612244897 || Balanced Log-Loss = 0.35876
# Trail # 9 || Using:  C=0.18367346938775508 || Balanced Log-Loss = 0.35366
# Trail #10 || Using:  C=0.2040816326530612 || Balanced Log-Loss = 0.34862
# Trail #11 || Using:  C=0.22448979591836732 || Balanced Log-Loss = 0.35660
# Trail #12 || Using:  C=0.24489795918367346 || Balanced Log-Loss = 0.36207
# Trail #13 || Using:  C=0.26530612244897955 || Balanced Log-Loss = 0.36210
# Trail #14 || Using:  C=0.2857142857142857 || Balanced Log-Loss = 0.36413
# Trail #15 || Using:  C=0.3061224489795918 || Balanced Log-Loss = 0.37339
# Trail #16 || Using:  C=0.32653061224489793 || Balanced Log-Loss = 0.37089
# Trail #17 || Using:  C=0.3469387755102041 || Balanced Log-Loss = 0.36641
# Trail #18 || Using:  C=0.36734693877551017 || Balanced Log-Loss = 0.38074
# Trail #19 || Using:  C=0.3877551020408163 || Balanced Log-Loss = 0.38119
# Trail #20 || Using:  C=0.4081632653061224 || Balanced Log-Loss = 0.37582
# Trail #21 || Using:  C=0.42857142857142855 || Balanced Log-Loss = 0.38439
# Trail #22 || Using:  C=0.44897959183673464 || Balanced Log-Loss = 0.39073
# Trail #23 || Using:  C=0.4693877551020408 || Balanced Log-Loss = 0.40927
# Trail #24 || Using:  C=0.4897959183673469 || Balanced Log-Loss = 0.40000
# Trail #25 || Using:  C=0.5102040816326531 || Balanced Log-Loss = 0.38373
# Trail #26 || Using:  C=0.5306122448979591 || Balanced Log-Loss = 0.41171
# Trail #27 || Using:  C=0.5510204081632653 || Balanced Log-Loss = 0.40125
# Trail #28 || Using:  C=0.5714285714285714 || Balanced Log-Loss = 0.40334
# Trail #29 || Using:  C=0.5918367346938775 || Balanced Log-Loss = 0.40477
# Trail #30 || Using:  C=0.6122448979591836 || Balanced Log-Loss = 0.42700
# Trail #31 || Using:  C=0.6326530612244897 || Balanced Log-Loss = 0.42597
# Trail #32 || Using:  C=0.6530612244897959 || Balanced Log-Loss = 0.43290
# Trail #33 || Using:  C=0.673469387755102 || Balanced Log-Loss = 0.44621
# Trail #34 || Using:  C=0.6938775510204082 || Balanced Log-Loss = 0.44273
# Trail #35 || Using:  C=0.7142857142857142 || Balanced Log-Loss = 0.44510
# Trail #36 || Using:  C=0.7346938775510203 || Balanced Log-Loss = 0.44059
# Trail #37 || Using:  C=0.7551020408163265 || Balanced Log-Loss = 0.45828
# Trail #38 || Using:  C=0.7755102040816326 || Balanced Log-Loss = 0.42964
# Trail #39 || Using:  C=0.7959183673469387 || Balanced Log-Loss = 0.45654
# Trail #40 || Using:  C=0.8163265306122448 || Balanced Log-Loss = 0.47409
# Trail #41 || Using:  C=0.836734693877551 || Balanced Log-Loss = 0.43369
# Trail #42 || Using:  C=0.8571428571428571 || Balanced Log-Loss = 0.44893
# Trail #43 || Using:  C=0.8775510204081632 || Balanced Log-Loss = 0.45176
# Trail #44 || Using:  C=0.8979591836734693 || Balanced Log-Loss = 0.45768
# Trail #45 || Using:  C=0.9183673469387754 || Balanced Log-Loss = 0.43539
# Trail #46 || Using:  C=0.9387755102040816 || Balanced Log-Loss = 0.45681
# Trail #47 || Using:  C=0.9591836734693877 || Balanced Log-Loss = 0.43457
# Trail #48 || Using:  C=0.9795918367346939 || Balanced Log-Loss = 0.45948
# Trail #49 || Using:  C=1.0 || Balanced Log-Loss = 0.45252
#
# *********************** FOLD #3 ***********************
#
# Trail # 1 || Using:  C=0.02040816326530612 || Balanced Log-Loss = 0.64124
# Trail # 2 || Using:  C=0.04081632653061224 || Balanced Log-Loss = 0.49584
# Trail # 3 || Using:  C=0.061224489795918366 || Balanced Log-Loss = 0.49462
# Trail # 4 || Using:  C=0.08163265306122448 || Balanced Log-Loss = 0.49418
# Trail # 5 || Using:  C=0.1020408163265306 || Balanced Log-Loss = 0.50332
# Trail # 6 || Using:  C=0.12244897959183673 || Balanced Log-Loss = 0.51274
# Trail # 7 || Using:  C=0.14285714285714285 || Balanced Log-Loss = 0.52030
# Trail # 8 || Using:  C=0.16326530612244897 || Balanced Log-Loss = 0.52622
# Trail # 9 || Using:  C=0.18367346938775508 || Balanced Log-Loss = 0.52736
# Trail #10 || Using:  C=0.2040816326530612 || Balanced Log-Loss = 0.52094
# Trail #11 || Using:  C=0.22448979591836732 || Balanced Log-Loss = 0.52784
# Trail #12 || Using:  C=0.24489795918367346 || Balanced Log-Loss = 0.52910
# Trail #13 || Using:  C=0.26530612244897955 || Balanced Log-Loss = 0.53857
# Trail #14 || Using:  C=0.2857142857142857 || Balanced Log-Loss = 0.54850
# Trail #15 || Using:  C=0.3061224489795918 || Balanced Log-Loss = 0.54990
# Trail #16 || Using:  C=0.32653061224489793 || Balanced Log-Loss = 0.55192
# Trail #17 || Using:  C=0.3469387755102041 || Balanced Log-Loss = 0.55273
# Trail #18 || Using:  C=0.36734693877551017 || Balanced Log-Loss = 0.57307
# Trail #19 || Using:  C=0.3877551020408163 || Balanced Log-Loss = 0.56571
# Trail #20 || Using:  C=0.4081632653061224 || Balanced Log-Loss = 0.57850
# Trail #21 || Using:  C=0.42857142857142855 || Balanced Log-Loss = 0.58449
# Trail #22 || Using:  C=0.44897959183673464 || Balanced Log-Loss = 0.59738
# Trail #23 || Using:  C=0.4693877551020408 || Balanced Log-Loss = 0.60927
# Trail #24 || Using:  C=0.4897959183673469 || Balanced Log-Loss = 0.59260
# Trail #25 || Using:  C=0.5102040816326531 || Balanced Log-Loss = 0.58832
# Trail #26 || Using:  C=0.5306122448979591 || Balanced Log-Loss = 0.61549
# Trail #27 || Using:  C=0.5510204081632653 || Balanced Log-Loss = 0.60663
# Trail #28 || Using:  C=0.5714285714285714 || Balanced Log-Loss = 0.59666
# Trail #29 || Using:  C=0.5918367346938775 || Balanced Log-Loss = 0.59277
# Trail #30 || Using:  C=0.6122448979591836 || Balanced Log-Loss = 0.60786
# Trail #31 || Using:  C=0.6326530612244897 || Balanced Log-Loss = 0.60557
# Trail #32 || Using:  C=0.6530612244897959 || Balanced Log-Loss = 0.59825
# Trail #33 || Using:  C=0.673469387755102 || Balanced Log-Loss = 0.60048
# Trail #34 || Using:  C=0.6938775510204082 || Balanced Log-Loss = 0.61225
# Trail #35 || Using:  C=0.7142857142857142 || Balanced Log-Loss = 0.61985
# Trail #36 || Using:  C=0.7346938775510203 || Balanced Log-Loss = 0.63542
# Trail #37 || Using:  C=0.7551020408163265 || Balanced Log-Loss = 0.63586
# Trail #38 || Using:  C=0.7755102040816326 || Balanced Log-Loss = 0.61259
# Trail #39 || Using:  C=0.7959183673469387 || Balanced Log-Loss = 0.61527
# Trail #40 || Using:  C=0.8163265306122448 || Balanced Log-Loss = 0.65283
# Trail #41 || Using:  C=0.836734693877551 || Balanced Log-Loss = 0.64699
# Trail #42 || Using:  C=0.8571428571428571 || Balanced Log-Loss = 0.65253
# Trail #43 || Using:  C=0.8775510204081632 || Balanced Log-Loss = 0.64661
# Trail #44 || Using:  C=0.8979591836734693 || Balanced Log-Loss = 0.63493
# Trail #45 || Using:  C=0.9183673469387754 || Balanced Log-Loss = 0.63828
# Trail #46 || Using:  C=0.9387755102040816 || Balanced Log-Loss = 0.63845
# Trail #47 || Using:  C=0.9591836734693877 || Balanced Log-Loss = 0.68463
# Trail #48 || Using:  C=0.9795918367346939 || Balanced Log-Loss = 0.67451
# Trail #49 || Using:  C=1.0 || Balanced Log-Loss = 0.67649
#
# *********************** FOLD #4 ***********************
#
# Trail # 1 || Using:  C=0.02040816326530612 || Balanced Log-Loss = 0.65277
# Trail # 2 || Using:  C=0.04081632653061224 || Balanced Log-Loss = 0.47364
# Trail # 3 || Using:  C=0.061224489795918366 || Balanced Log-Loss = 0.45817
# Trail # 4 || Using:  C=0.08163265306122448 || Balanced Log-Loss = 0.47041
# Trail # 5 || Using:  C=0.1020408163265306 || Balanced Log-Loss = 0.46705
# Trail # 6 || Using:  C=0.12244897959183673 || Balanced Log-Loss = 0.49022
# Trail # 7 || Using:  C=0.14285714285714285 || Balanced Log-Loss = 0.48756
# Trail # 8 || Using:  C=0.16326530612244897 || Balanced Log-Loss = 0.50173
# Trail # 9 || Using:  C=0.18367346938775508 || Balanced Log-Loss = 0.50574
# Trail #10 || Using:  C=0.2040816326530612 || Balanced Log-Loss = 0.50333
# Trail #11 || Using:  C=0.22448979591836732 || Balanced Log-Loss = 0.51806
# Trail #12 || Using:  C=0.24489795918367346 || Balanced Log-Loss = 0.52892
# Trail #13 || Using:  C=0.26530612244897955 || Balanced Log-Loss = 0.54823
# Trail #14 || Using:  C=0.2857142857142857 || Balanced Log-Loss = 0.54688
# Trail #15 || Using:  C=0.3061224489795918 || Balanced Log-Loss = 0.53843
# Trail #16 || Using:  C=0.32653061224489793 || Balanced Log-Loss = 0.55395
# Trail #17 || Using:  C=0.3469387755102041 || Balanced Log-Loss = 0.55176
# Trail #18 || Using:  C=0.36734693877551017 || Balanced Log-Loss = 0.56142
# Trail #19 || Using:  C=0.3877551020408163 || Balanced Log-Loss = 0.56299
# Trail #20 || Using:  C=0.4081632653061224 || Balanced Log-Loss = 0.54388
# Trail #21 || Using:  C=0.42857142857142855 || Balanced Log-Loss = 0.59110
# Trail #22 || Using:  C=0.44897959183673464 || Balanced Log-Loss = 0.60937
# Trail #23 || Using:  C=0.4693877551020408 || Balanced Log-Loss = 0.58442
# Trail #24 || Using:  C=0.4897959183673469 || Balanced Log-Loss = 0.62657
# Trail #25 || Using:  C=0.5102040816326531 || Balanced Log-Loss = 0.59477
# Trail #26 || Using:  C=0.5306122448979591 || Balanced Log-Loss = 0.60247
# Trail #27 || Using:  C=0.5510204081632653 || Balanced Log-Loss = 0.62831
# Trail #28 || Using:  C=0.5714285714285714 || Balanced Log-Loss = 0.62332
# Trail #29 || Using:  C=0.5918367346938775 || Balanced Log-Loss = 0.61856
# Trail #30 || Using:  C=0.6122448979591836 || Balanced Log-Loss = 0.64547
# Trail #31 || Using:  C=0.6326530612244897 || Balanced Log-Loss = 0.61413
# Trail #32 || Using:  C=0.6530612244897959 || Balanced Log-Loss = 0.62305
# Trail #33 || Using:  C=0.673469387755102 || Balanced Log-Loss = 0.63975
# Trail #34 || Using:  C=0.6938775510204082 || Balanced Log-Loss = 0.62026
# Trail #35 || Using:  C=0.7142857142857142 || Balanced Log-Loss = 0.68507
# Trail #36 || Using:  C=0.7346938775510203 || Balanced Log-Loss = 0.65106
# Trail #37 || Using:  C=0.7551020408163265 || Balanced Log-Loss = 0.65641
# Trail #38 || Using:  C=0.7755102040816326 || Balanced Log-Loss = 0.64315
# Trail #39 || Using:  C=0.7959183673469387 || Balanced Log-Loss = 0.67579
# Trail #40 || Using:  C=0.8163265306122448 || Balanced Log-Loss = 0.69927
# Trail #41 || Using:  C=0.836734693877551 || Balanced Log-Loss = 0.69706
# Trail #42 || Using:  C=0.8571428571428571 || Balanced Log-Loss = 0.72127
# Trail #43 || Using:  C=0.8775510204081632 || Balanced Log-Loss = 0.64797
# Trail #44 || Using:  C=0.8979591836734693 || Balanced Log-Loss = 0.65324
# Trail #45 || Using:  C=0.9183673469387754 || Balanced Log-Loss = 0.70650
# Trail #46 || Using:  C=0.9387755102040816 || Balanced Log-Loss = 0.71620
# Trail #47 || Using:  C=0.9591836734693877 || Balanced Log-Loss = 0.72174
# Trail #48 || Using:  C=0.9795918367346939 || Balanced Log-Loss = 0.68641
# Trail #49 || Using:  C=1.0 || Balanced Log-Loss = 0.70151

# %%
# store each fold's metrics in array
accs_total = np.array(accs_total)
blls_total = np.array(blls_total)


accs_CV_est = np.mean(accs_total, axis=0)
blls_CV_est = np.mean(blls_total, axis=0)

print(f'Trial #{np.argsort(blls_CV_est)[0]+1} had the lowest balanced log-loss at {np.sort(blls_CV_est)[0]}.')


figure, axis = plt.subplots(2, 1, figsize=(10, 10))
  
axis[0].plot(accs_CV_est)
axis[0].set_title("5 Fold-CV Validation Accuracy Est.")
  
axis[1].plot(blls_CV_est)
axis[1].set_title("5 Fold-CV Validation Balanced Log-Loss Est.")


plt.show()
# Out:
# Trial #10 had the lowest balanced log-loss at 0.44331289190929946.

# %% [markdown]
# Trial \#10 seems to have the best combination of low balanced log-loss and high accuracy across our validation sets. This corresponds to a C=0.204082. The final estimated balanced log-loss was 0.443312.

# %% [markdown]
# ### Output Probabilties
#
# We first generate probabilities for the *official* validaiton set with tuned hyperparameters.

# %%
# load training data
train_df = pd.read_csv(TRAIN_DATA)

# allocate
X = train_df.drop(columns=['Class', 'Id'])
X = pd.get_dummies(X, drop_first=True)

y = train_df['Class'].astype(int)

# train-validation split 
X_train_raw, X_val, y_train_raw, y_val = train_test_split(X, y, test_size=0.20, random_state=42)

X_val['EJ_B'].fillna(value=X_train_raw['EJ_B'].mode())
X_val = X_val.fillna(value=X_train_raw.mean())

X_train_raw['EJ_B'].fillna(value=X_train_raw['EJ_B'].mode())
X_train_raw = X_train_raw.fillna(value=X_train_raw.mean())

# over sample the diagnosed patients in training set
oversample = SMOTE(random_state=77, sampling_strategy='minority')
X_train, y_train = oversample.fit_resample(X_train_raw, y_train_raw)

# shuffle (in case the model choice may be impacted by ordering)
np.random.seed(77)
shuff_ind = np.random.choice(len(y_train), len(y_train), replace=False)

X_train = X_train.iloc[shuff_ind,]
y_train = y_train.iloc[shuff_ind,]

# fit TabPFN with optimal hyperparams 
classifier = make_pipeline(StandardScaler(), SVC(gamma='auto', 
                                                 kernel='rbf', 
                                                 C=0.204082, 
                                                 probability=True))
classifier.fit(X_train, y_train)

# collect train probabilities 
probs = classifier.predict_proba(X_train.dropna())

# store the train-set predictions in csv format, locally.
pd.DataFrame(probs).to_csv("train_pred_probs/svm-tuned.csv", header=True, index=False)

# collect val probabilities 
probs = classifier.predict_proba(X_val.dropna())

# store the validation-set predictions in csv format, locally.
pd.DataFrame(probs).to_csv("val_pred_probs/svm-tuned.csv", header=True, index=False)

# %% [markdown]
# Then we generate the probabilites for the test set (for submission).

# %%
# fit TabPFN with optimal hyperparams 
classifier = make_pipeline(StandardScaler(), SVC(gamma='auto', 
                                                 kernel='rbf', 
                                                 C=0.204082, 
                                                 probability=True))

# fill NaNs
X['EJ_B'].fillna(value=X['EJ_B'].mode())
X = X.fillna(value=X.mean())

# over sample the diagnosed patients in training set
oversample = SMOTE(random_state=77, sampling_strategy='minority')
X_rs, y_rs = oversample.fit_resample(X, y)

# shuffle (in case the model choice may be impacted by ordering)
shuff_ind = np.random.choice(len(y_rs), len(y_rs), replace=False)
X_rs = X_rs.iloc[shuff_ind,]
y_rs = y_rs.iloc[shuff_ind,]

# fit xgboost model
classifier.fit(X_rs, y_rs)

# load testing data
test_df = pd.read_csv(TEST_DATA)
test_df['EJ_B'] = (test_df['EJ'] == 'B').astype('int')
X_test = test_df.drop(columns=['Id', 'EJ'])

# collect test probabilities 
probs = classifier.predict_proba(X_test)

# store the test-set predictions in csv format, locally.
pd.DataFrame(probs).to_csv("test_pred_probs/svm-tuned.csv", header=True, index=False)
